# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np

# %%
left_to_center = {'av': {'OP': 13033, 'IP': 0, 'IN': 0, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'ds': {'OP': 0, 'IP': 170172, 'IN': 0, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'dtp': {'OP': 0, 'IP': 0, 'IN': 294835, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'en': {'OP': 0, 'IP': 0, 'IN': 3103, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'fi': {'OP': 0, 'IP': 0, 'IN': 741, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'it': {'OP': 0, 'IP': 0, 'IN': 0, 'SP': 3292, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'lt': {'OP': 0, 'IP': 0, 'IN': 2292, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'nb': {'OP': 0, 'IP': 0, 'IN': 0, 'SP': 0, 'NA': 60923, 'HI': 0, 'LY': 1, 'ID': 1}, 'ne': {'OP': 0, 'IP': 0, 'IN': 0, 'SP': 0, 'NA': 131236, 'HI': 0, 'LY': 1, 'ID': 1}, 'ob': {'OP': 24482, 'IP': 0, 'IN': 0, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'ra': {'OP': 0, 'IP': 0, 'IN': 17962, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 're': {'OP': 0, 'IP': 0, 'IN': 0, 'SP': 0, 'NA': 0, 'HI': 7495, 'LY': 1, 'ID': 1}, 'rs': {'OP': 14353, 'IP': 0, 'IN': 0, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'rv': {'OP': 26240, 'IP': 0, 'IN': 0, 'SP': 0, 'NA': 0, 'HI': 0, 'LY': 1, 'ID': 1}, 'sr': {'OP': 0, 'IP': 0, 'IN': 0, 'SP': 0, 'NA': 26709, 'HI': 0, 'LY': 1, 'ID': 1}}

center_to_right = {'HI': {'Cookbooks, Food & Wine': 6880, 'Engineering & Transportation': 5893, 'Literature & Fiction': 3862, 'Medicine & Health Sciences': 885, 'None': 15120, 'Politics & Social Sciences': 10243, 'Science & Math': 986}, 'ID': {'Cookbooks, Food & Wine': 259, 'Engineering & Transportation': 8774, 'Literature & Fiction': 19054, 'Medicine & Health Sciences': 1289, 'None': 12281, 'Politics & Social Sciences': 8331, 'Science & Math': 1014}, 'IN': {'Cookbooks, Food & Wine': 2498
medicine & Health Sciences': 16, 'None': 23, 'Politics & Social Sciences': 68, 'Science & Math': 20}, 'Narrative': {'Cookbooks, Food & Wine': 475, 'Engineering & Transportation': 18613, 'Literature & Fiction': 120716, 'Medicine & Health Sciences': 6427, 'None': 43758, 'Politics & Social Sciences': 101002, 'Science & Math': 3755}, 'Opinion': {'Cookbooks, Food & Wine': 723, 'Engineering & Transportation': 5994, 'Literature & Fiction': 55650, 'Medicine & Health Sciences': 2780, 'None': 22067, 'Politics & Social Sciences': 49879, 'Science & Math': 292}, 'Spoken': {'Cookbooks, Food & Wine': 4, 'Engineering & Transportation': 166, 'Literature & Fiction': 2174, 'Medicine & Health Sciences': 105, 'None': 434, 'Politics & Social Sciences': 1431, 'Science & Math': 30}}

# %%
base_color='68,27,35'

def plot_sankey(left_to_center, center_to_right):
    
    def extract_nodes_links(left_to_center, center_to_right):
        left_nodes = list(left_to_center.keys())
        center_nodes = sorted(list(set([node for center in left_to_center.values() for node in center.keys()])))
        right_nodes = sorted(list(set([node for right in center_to_right.values() for node in right.keys()])))
    
        nodes = left_nodes + center_nodes + right_nodes
    
        # Create the links
        links = {
            'source': [],
            'target': [],
            'value': [],
            'color': []
        }

        def yield_opacity(x):
            return str(x/5.0 + 0.01)
                
        # Left to center links
        for left, centers in left_to_center.items():
            values = list(centers.values())
            max_value = max([i for i in values])
            #print("MAX", max_value)
            for center, value in centers.items():
                links['source'].append(nodes.index(left))
                links['target'].append(nodes.index(center))
                links['value'].append(value)
                opacity = yield_opacity(value/max_value)
                color = f'rgba({base_color}, {opacity})' if value != 1 else f'rgba({base_color}, 0)'
                links['color'].append(color)
    
        # Center to right links
        for center, rights in center_to_right.items():
            values = list(rights.values())
            max_value = max([i for i in values])
            #print("MAX", max_value)
            for right, value in rights.items():
                links['source'].append(nodes.index(center))
                links['target'].append(nodes.index(right))
                links['value'].append(value)
                opacity = yield_opacity(value/max_value)
                color = f'rgba({base_color}, {opacity})' if value != 1 else f'rgba({base_color}, 0)'
                links['color'].append(color)

        return nodes, links
    
    nodes, links = extract_nodes_links(left_to_center, center_to_right)
    #print("nodes = ",nodes)
    #print("links = ",links)

    # Create the Sankey diagram
    fig = go.Figure(go.Sankey(
        node=dict(
            pad=15,
            thickness=20,
            color="grey",
            line=dict(color="black", width=0.5),
            label=nodes
        ),
        link=dict(
            source=links['source'],
            target=links['target'],
            value=links['value'],
            color=links['color']
        )
    ))
    
    fig.update_layout(
        font=dict(
            family="Arial",
            size=40
        ),
        title_text="",
        width=1500,
        height=1000
    )
    fig.show()
    return fig
    #fig.write_image()

# %%
fig = plot_sankey(left_to_center, center_to_right)

# %%
fig.write_image("plot.svg")
