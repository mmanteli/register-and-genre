# %% [markdown]
# ## Reading all results cross-labelwise

# %%
with open("1topics_10words_large_data.txt", "r") as f1, open("2topics_10words_large_data.txt", "r") as f2, open("3topics_10words_large_data.txt", "r") as f3:
    t1 = " ".join(f1.readlines()).split("---------------------------")
    t2 = " ".join(f2.readlines()).split("---------------------------")
    t3 = " ".join(f3.readlines()).split("---------------------------")
    for e,(i,j,k) in enumerate(zip(t1, t2, t3)):
        if e == 0:
            continue
        label = i.split("\n")[1]
        support = i.split("\n")[2]
        if "MT" in label:
            continue
        if "Not enough data" in support:
            continue
        print(f'Label {label[9:-1]}')
        print(f'{support}')
        print("1 TOPIC:")
        print("\n".join(i.split("\n")[3:]))
        print("2 TOPICS:")
        print("\n".join(j.split("\n")[3:]))
        print("3 TOPICS:")
        print("\n".join(k.split("\n")[3:]))
        print("-----------------------")
# Out:
# Label 'HI', 'Cookbooks, Food & Wine'
#  Support is 6838
# 1 TOPIC:
#  [(0,
#    '0.004*"make" + 0.004*"one" + 0.004*"add" + 0.004*"like" + 0.003*"recipe" + '
#    '0.003*"time" + 0.003*"minutes" + 0.003*"also" + 0.003*"use" + 0.002*"get"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"like" + 0.003*"time" + 0.003*"get" + '
#    '0.003*"make" + 0.003*"may" + 0.002*"would" + 0.002*"people" + 0.002*"new"'),
#   (1,
#    '0.006*"add" + 0.006*"make" + 0.005*"recipe" + 0.005*"minutes" + 0.005*"one" '
#    '+ 0.004*"like" + 0.004*"water" + 0.004*"use" + 0.003*"time" + 0.003*"heat"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"coffee" + 0.002*"corn" + 0.002*"turkey" + 0.002*"wine" + '
#    '0.002*"soybean" + 0.001*"may" + 0.001*"get" + 0.001*"year" + '
#    '0.001*"quarter" + 0.001*"think"'),
#   (1,
#    '0.007*"add" + 0.006*"make" + 0.006*"recipe" + 0.005*"minutes" + '
#    '0.005*"like" + 0.004*"one" + 0.004*"water" + 0.004*"use" + 0.004*"time" + '
#    '0.003*"made"'),
#   (2,
#    '0.005*"one" + 0.003*"like" + 0.003*"time" + 0.003*"also" + 0.003*"get" + '
#    '0.003*"new" + 0.003*"would" + 0.003*"make" + 0.002*"people" + 0.002*"may"')]
#
#
# -----------------------
# Label 'HI', 'Engineering & Transportation'
#  Support is 5875
# 1 TOPIC:
#  [(0,
#    '0.004*"use" + 0.004*"one" + 0.003*"also" + 0.003*"need" + 0.003*"make" + '
#    '0.003*"time" + 0.003*"get" + 0.003*"may" + 0.003*"new" + 0.002*"like"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"use" + 0.003*"one" + 0.003*"using" + 0.003*"also" + 0.003*"file" + '
#    '0.003*"data" + 0.003*"need" + 0.003*"used" + 0.003*"may" + 0.002*"time"'),
#   (1,
#    '0.004*"one" + 0.003*"also" + 0.003*"use" + 0.003*"make" + 0.003*"get" + '
#    '0.003*"time" + 0.003*"may" + 0.003*"need" + 0.003*"like" + 0.003*"new"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"use" + 0.004*"one" + 0.003*"also" + 0.003*"using" + 0.003*"used" + '
#    '0.003*"need" + 0.003*"data" + 0.003*"may" + 0.002*"file" + 0.002*"device"'),
#   (1,
#    '0.004*"one" + 0.004*"make" + 0.003*"get" + 0.003*"also" + 0.003*"use" + '
#    '0.003*"may" + 0.003*"time" + 0.003*"need" + 0.003*"home" + 0.003*"like"'),
#   (2,
#    '0.004*"use" + 0.003*"new" + 0.003*"also" + 0.003*"may" + 0.003*"need" + '
#    '0.003*"one" + 0.003*"file" + 0.003*"data" + 0.002*"time" + 0.002*"using"')]
#
#
# -----------------------
# Label 'HI', 'Literature & Fiction'
#  Support is 3815
# 1 TOPIC:
#  [(0,
#    '0.005*"one" + 0.004*"like" + 0.004*"make" + 0.004*"get" + 0.003*"time" + '
#    '0.003*"also" + 0.003*"love" + 0.003*"new" + 0.003*"use" + 0.002*"would"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"one" + 0.005*"make" + 0.004*"like" + 0.004*"love" + 0.004*"get" + '
#    '0.003*"time" + 0.003*"also" + 0.003*"new" + 0.003*"would" + 0.003*"use"'),
#   (1,
#    '0.004*"one" + 0.003*"time" + 0.003*"get" + 0.003*"also" + 0.003*"like" + '
#    '0.003*"use" + 0.002*"make" + 0.002*"new" + 0.002*"would" + 0.002*"game"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.004*"game" + 0.002*"get" + 0.002*"would" + 0.002*"make" + '
#    '0.002*"two" + 0.002*"like" + 0.002*"sonoa" + 0.002*"–" + 0.002*"first"'),
#   (1,
#    '0.005*"one" + 0.004*"also" + 0.004*"like" + 0.003*"time" + 0.003*"get" + '
#    '0.003*"new" + 0.003*"make" + 0.003*"use" + 0.002*"may" + 0.002*"first"'),
#   (2,
#    '0.006*"one" + 0.005*"make" + 0.005*"like" + 0.005*"love" + 0.004*"get" + '
#    '0.004*"time" + 0.003*"use" + 0.003*"little" + 0.003*"card" + 0.003*"would"')]
#
#
# -----------------------
# Label 'HI', 'Medicine & Health Sciences'
#  Support is 877
# 1 TOPIC:
#  [(0,
#    '0.004*"also" + 0.004*"get" + 0.004*"one" + 0.003*"skin" + 0.003*"may" + '
#    '0.003*"time" + 0.003*"help" + 0.003*"use" + 0.003*"make" + 0.003*"like"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"also" + 0.004*"get" + 0.004*"help" + 0.004*"one" + 0.004*"back" + '
#    '0.004*"may" + 0.003*"hair" + 0.003*"use" + 0.003*"make" + 0.003*"body"'),
#   (1,
#    '0.005*"skin" + 0.004*"one" + 0.004*"time" + 0.004*"also" + 0.003*"get" + '
#    '0.003*"may" + 0.003*"use" + 0.003*"make" + 0.003*"like" + 0.003*"help"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.007*"skin" + 0.006*"also" + 0.005*"get" + 0.005*"help" + 0.004*"one" + '
#    '0.004*"use" + 0.004*"may" + 0.004*"make" + 0.004*"body" + 0.003*"hair"'),
#   (1,
#    '0.005*"teeth" + 0.003*"one" + 0.003*"blood" + 0.003*"also" + 0.003*"use" + '
#    '0.003*"time" + 0.002*"may" + 0.002*"pressure" + 0.002*"help" + '
#    '0.002*"make"'),
#   (2,
#    '0.004*"one" + 0.004*"time" + 0.004*"get" + 0.003*"may" + 0.003*"also" + '
#    '0.003*"like" + 0.003*"people" + 0.003*"need" + 0.003*"make" + '
#    '0.002*"first"')]
#
#
# -----------------------
# Label 'HI', 'None'
#  Support is 15023
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.003*"make" + 0.003*"also" + 0.003*"like" + 0.003*"time" + '
#    '0.003*"use" + 0.003*"get" + 0.002*"new" + 0.002*"need" + 0.002*"may"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"like" + 0.003*"also" + 0.003*"make" + 0.002*"new" + '
#    '0.002*"use" + 0.002*"time" + 0.002*"get" + 0.002*"would" + 0.002*"us"'),
#   (1,
#    '0.005*"one" + 0.004*"make" + 0.004*"get" + 0.004*"like" + 0.004*"use" + '
#    '0.004*"time" + 0.004*"also" + 0.003*"need" + 0.003*"want" + 0.002*"way"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"2" + 0.003*"also" + 0.003*"make" + 0.003*"like" + '
#    '0.003*"weight" + 0.002*"would" + 0.002*"first" + 0.002*"lg" + 0.002*"get"'),
#   (1,
#    '0.005*"one" + 0.005*"make" + 0.004*"get" + 0.004*"like" + 0.004*"time" + '
#    '0.003*"also" + 0.003*"new" + 0.003*"use" + 0.003*"need" + 0.003*"want"'),
#   (2,
#    '0.004*"use" + 0.003*"one" + 0.003*"file" + 0.003*"also" + 0.003*"like" + '
#    '0.003*"may" + 0.003*"make" + 0.003*"new" + 0.003*"need" + 0.002*"using"')]
#
#
# -----------------------
# Label 'HI', 'Politics & Social Sciences'
#  Support is 10219
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.004*"use" + 0.004*"also" + 0.003*"make" + 0.003*"get" + '
#    '0.003*"time" + 0.003*"need" + 0.003*"like" + 0.003*"may" + 0.003*"new"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"use" + 0.004*"one" + 0.004*"also" + 0.003*"using" + 0.003*"need" + '
#    '0.003*"see" + 0.003*"site" + 0.003*"email" + 0.003*"get" + 0.003*"page"'),
#   (1,
#    '0.004*"one" + 0.004*"make" + 0.004*"time" + 0.004*"get" + 0.003*"also" + '
#    '0.003*"may" + 0.003*"business" + 0.003*"like" + 0.003*"need" + '
#    '0.003*"people"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.005*"use" + 0.005*"file" + 0.004*"one" + 0.004*"data" + 0.003*"need" + '
#    '0.003*"also" + 0.003*"using" + 0.003*"new" + 0.003*"pdf" + 0.003*"server"'),
#   (1,
#    '0.005*"get" + 0.004*"make" + 0.004*"one" + 0.004*"time" + 0.004*"also" + '
#    '0.003*"people" + 0.003*"need" + 0.003*"like" + 0.003*"may" + 0.003*"help"'),
#   (2,
#    '0.004*"email" + 0.003*"one" + 0.003*"new" + 0.003*"use" + 0.002*"account" + '
#    '0.002*"make" + 0.002*"also" + 0.002*"video" + 0.002*"may" + '
#    '0.002*"facebook"')]
#
#
# -----------------------
# Label 'HI', 'Science & Math'
#  Support is 975
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.004*"use" + 0.004*"also" + 0.003*"time" + 0.003*"water" + '
#    '0.003*"like" + 0.003*"may" + 0.003*"get" + 0.003*"make" + 0.002*"need"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"use" + 0.005*"one" + 0.004*"also" + 0.003*"data" + 0.003*"function" '
#    '+ 0.003*"used" + 0.003*"using" + 0.003*"value" + 0.003*"number" + '
#    '0.003*"see"'),
#   (1,
#    '0.005*"water" + 0.004*"one" + 0.004*"plants" + 0.004*"also" + 0.003*"plant" '
#    '+ 0.003*"time" + 0.003*"like" + 0.003*"may" + 0.003*"make" + 0.003*"get"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.004*"students" + 0.003*"get" + 0.003*"like" + 0.003*"also" '
#    '+ 0.003*"use" + 0.003*"make" + 0.003*"time" + 0.002*"may" + 0.002*"need"'),
#   (1,
#    '0.005*"use" + 0.005*"one" + 0.004*"data" + 0.004*"function" + 0.004*"also" '
#    '+ 0.004*"value" + 0.004*"used" + 0.003*"number" + 0.003*"using" + '
#    '0.003*"see"'),
#   (2,
#    '0.007*"water" + 0.005*"plants" + 0.004*"plant" + 0.004*"garden" + '
#    '0.004*"also" + 0.004*"soil" + 0.004*"one" + 0.003*"time" + 0.003*"fish" + '
#    '0.003*"make"')]
#
#
# -----------------------
# Label 'ID', 'Cookbooks, Food & Wine'
#  Support is 256
# 1 TOPIC:
#  [(0,
#    '0.005*"like" + 0.004*"rustic" + 0.004*"one" + 0.004*"home" + 0.004*"plans" '
#    '+ 0.004*"house" + 0.003*"would" + 0.003*"use" + 0.003*"make" + 0.003*"get"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.019*"rustic" + 0.017*"plans" + 0.016*"house" + 0.015*"home" + '
#    '0.012*"kitchen" + 0.012*"room" + 0.012*"country" + 0.010*"design" + '
#    '0.010*"furniture" + 0.010*"ideas"'),
#   (1,
#    '0.006*"like" + 0.005*"one" + 0.004*"would" + 0.004*"make" + 0.004*"use" + '
#    '0.004*"get" + 0.003*"time" + 0.003*"good" + 0.003*"also" + 0.003*"recipe"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.007*"like" + 0.005*"would" + 0.005*"make" + 0.004*"one" + 0.004*"use" + '
#    '0.004*"good" + 0.004*"recipe" + 0.004*"also" + 0.003*"well" + 0.003*"get"'),
#   (1,
#    '0.022*"rustic" + 0.020*"plans" + 0.018*"house" + 0.017*"home" + '
#    '0.014*"kitchen" + 0.014*"country" + 0.014*"room" + 0.012*"design" + '
#    '0.012*"furniture" + 0.011*"ideas"'),
#   (2,
#    '0.005*"like" + 0.004*"one" + 0.004*"would" + 0.004*"use" + 0.004*"get" + '
#    '0.003*"time" + 0.003*"water" + 0.003*"make" + 0.003*"also" + 0.003*"think"')]
#
#
# -----------------------
# Label 'ID', 'Engineering & Transportation'
#  Support is 8759
# 1 TOPIC:
#  [(0,
#    '0.005*"would" + 0.005*"one" + 0.004*"like" + 0.004*"get" + 0.003*"new" + '
#    '0.003*"also" + 0.003*"use" + 0.003*"time" + 0.003*"need" + 0.002*"work"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.004*"would" + 0.004*"get" + 0.003*"new" + 0.003*"like" + '
#    '0.003*"time" + 0.003*"also" + 0.003*"use" + 0.002*"work" + 0.002*"4040"'),
#   (1,
#    '0.005*"one" + 0.005*"like" + 0.005*"would" + 0.004*"get" + 0.003*"also" + '
#    '0.003*"time" + 0.003*"new" + 0.003*"use" + 0.003*"need" + 0.003*"good"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"would" + 0.003*"one" + 0.003*"like" + 0.003*"time" + 0.003*"also" + '
#    '0.003*"get" + 0.003*"new" + 0.002*"use" + 0.002*"good" + 0.002*"see"'),
#   (1,
#    '0.005*"one" + 0.005*"would" + 0.005*"get" + 0.005*"like" + 0.004*"use" + '
#    '0.003*"new" + 0.003*"also" + 0.003*"time" + 0.003*"need" + 0.003*"im"'),
#   (2,
#    '0.004*"one" + 0.004*"would" + 0.004*"like" + 0.004*"get" + 0.003*"need" + '
#    '0.003*"use" + 0.003*"time" + 0.003*"also" + 0.003*"new" + 0.002*"work"')]
#
#
# -----------------------
# Label 'ID', 'Literature & Fiction'
#  Support is 18947
# 1 TOPIC:
#  [(0,
#    '0.006*"like" + 0.005*"one" + 0.004*"would" + 0.004*"get" + 0.004*"time" + '
#    '0.003*"im" + 0.003*"know" + 0.003*"also" + 0.003*"good" + 0.003*"think"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"one" + 0.005*"like" + 0.004*"would" + 0.004*"new" + 0.003*"get" + '
#    '0.003*"time" + 0.003*"dating" + 0.003*"im" + 0.003*"also" + 0.003*"think"'),
#   (1,
#    '0.005*"like" + 0.005*"one" + 0.005*"would" + 0.004*"get" + 0.004*"time" + '
#    '0.004*"good" + 0.003*"im" + 0.003*"think" + 0.003*"people" + '
#    '0.003*"really"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.007*"like" + 0.006*"one" + 0.005*"would" + 0.005*"get" + 0.004*"time" + '
#    '0.003*"im" + 0.003*"think" + 0.003*"know" + 0.003*"people" + 0.003*"also"'),
#   (1,
#    '0.003*"looking" + 0.003*"would" + 0.002*"one" + 0.002*"like" + 0.002*"also" '
#    '+ 0.002*"get" + 0.002*"time" + 0.002*"im" + 0.002*"sex" + 0.002*"good"'),
#   (2,
#    '0.006*"firstperson" + 0.006*"twentiethcentury" + 0.005*"post" + 0.004*"two" '
#    '+ 0.004*"no" + 0.004*"one" + 0.004*"novel" + 0.004*"like" + '
#    '0.004*"unreliability" + 0.003*"hotel"')]
#
#
# -----------------------
# Label 'ID', 'Medicine & Health Sciences'
#  Support is 1278
# 1 TOPIC:
#  [(0,
#    '0.004*"get" + 0.004*"one" + 0.004*"like" + 0.004*"would" + 0.004*"time" + '
#    '0.004*"also" + 0.003*"know" + 0.002*"may" + 0.002*"good" + 0.002*"im"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"also" + 0.003*"may" + 0.002*"patients" + 0.002*"cancer" + '
#    '0.002*"new" + 0.002*"treatment" + 0.002*"one" + 0.002*"health" + 0.002*"1" '
#    '+ 0.002*"cells"'),
#   (1,
#    '0.006*"get" + 0.005*"like" + 0.005*"one" + 0.005*"would" + 0.004*"time" + '
#    '0.004*"also" + 0.004*"know" + 0.003*"im" + 0.003*"back" + 0.003*"good"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"since" + 0.004*"patient" + 0.003*"—" + 0.003*"hip" + 0.003*"000000" '
#    '+ 0.003*"teeth" + 0.003*"pain" + 0.002*"dental" + 0.002*"dentist" + '
#    '0.002*"may"'),
#   (1,
#    '0.006*"get" + 0.005*"like" + 0.005*"would" + 0.005*"one" + 0.004*"time" + '
#    '0.004*"know" + 0.004*"also" + 0.003*"im" + 0.003*"day" + 0.003*"good"'),
#   (2,
#    '0.003*"one" + 0.003*"also" + 0.003*"use" + 0.002*"like" + 0.002*"would" + '
#    '0.002*"time" + 0.002*"may" + 0.002*"get" + 0.002*"people" + 0.002*"using"')]
#
#
# -----------------------
# Label 'ID', 'None'
#  Support is 12272
# 1 TOPIC:
#  [(0,
#    '0.005*"like" + 0.005*"one" + 0.004*"would" + 0.004*"get" + 0.003*"also" + '
#    '0.003*"time" + 0.003*"use" + 0.003*"new" + 0.003*"know" + 0.003*"need"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"one" + 0.005*"like" + 0.004*"would" + 0.003*"get" + 0.003*"time" + '
#    '0.003*"people" + 0.003*"also" + 0.003*"think" + 0.003*"know" + '
#    '0.002*"good"'),
#   (1,
#    '0.004*"one" + 0.004*"like" + 0.004*"get" + 0.004*"would" + 0.003*"time" + '
#    '0.003*"also" + 0.003*"use" + 0.003*"need" + 0.003*"new" + 0.003*"im"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.005*"like" + 0.005*"one" + 0.004*"would" + 0.004*"get" + 0.004*"time" + '
#    '0.004*"good" + 0.003*"home" + 0.003*"think" + 0.003*"also" + '
#    '0.003*"people"'),
#   (1,
#    '0.002*"one" + 0.002*"new" + 0.002*"–" + 0.002*"would" + 0.002*"also" + '
#    '0.002*"time" + 0.002*"like" + 0.002*"need" + 0.002*"design" + '
#    '0.002*"windows"'),
#   (2,
#    '0.005*"like" + 0.005*"get" + 0.005*"would" + 0.004*"one" + 0.004*"also" + '
#    '0.004*"use" + 0.004*"im" + 0.003*"time" + 0.003*"need" + 0.003*"know"')]
#
#
# -----------------------
# Label 'ID', 'Politics & Social Sciences'
#  Support is 8300
# 1 TOPIC:
#  [(0,
#    '0.005*"would" + 0.005*"one" + 0.004*"like" + 0.004*"get" + 0.003*"time" + '
#    '0.003*"people" + 0.003*"also" + 0.003*"need" + 0.003*"us" + 0.003*"know"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"one" + 0.005*"people" + 0.004*"would" + 0.004*"us" + 0.003*"like" + '
#    '0.003*"god" + 0.003*"time" + 0.003*"think" + 0.003*"know" + 0.002*"even"'),
#   (1,
#    '0.005*"would" + 0.005*"like" + 0.004*"get" + 0.004*"one" + 0.004*"need" + '
#    '0.003*"time" + 0.003*"also" + 0.003*"want" + 0.003*"use" + 0.003*"new"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.006*"need" + 0.005*"like" + 0.005*"website" + 0.005*"would" + 0.004*"get" '
#    '+ 0.004*"use" + 0.004*"work" + 0.004*"want" + 0.004*"one" + '
#    '0.003*"records"'),
#   (1,
#    '0.005*"would" + 0.005*"one" + 0.004*"like" + 0.003*"get" + 0.003*"people" + '
#    '0.003*"also" + 0.003*"time" + 0.003*"know" + 0.003*"think" + 0.002*"may"'),
#   (2,
#    '0.005*"would" + 0.005*"people" + 0.005*"one" + 0.004*"like" + 0.003*"get" + '
#    '0.003*"time" + 0.003*"think" + 0.003*"us" + 0.003*"know" + 0.003*"also"')]
#
#
# -----------------------
# Label 'ID', 'Science & Math'
#  Support is 1001
# 1 TOPIC:
#  [(0,
#    '0.005*"one" + 0.005*"would" + 0.004*"like" + 0.004*"get" + 0.003*"time" + '
#    '0.003*"also" + 0.002*"know" + 0.002*"new" + 0.002*"good" + 0.002*"use"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"plants" + 0.003*"would" + 0.002*"also" + 0.002*"like" '
#    '+ 0.002*"2" + 0.002*"use" + 0.002*"two" + 0.002*"time" + 0.002*"order"'),
#   (1,
#    '0.005*"one" + 0.005*"would" + 0.004*"like" + 0.004*"get" + 0.004*"time" + '
#    '0.003*"also" + 0.003*"new" + 0.003*"know" + 0.003*"good" + 0.002*"think"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.005*"one" + 0.005*"would" + 0.005*"get" + 0.004*"like" + 0.004*"time" + '
#    '0.003*"also" + 0.003*"think" + 0.003*"know" + 0.002*"use" + 0.002*"see"'),
#   (1,
#    '0.005*"one" + 0.004*"would" + 0.004*"like" + 0.004*"time" + 0.003*"get" + '
#    '0.003*"also" + 0.002*"new" + 0.002*"first" + 0.002*"see" + 0.002*"may"'),
#   (2,
#    '0.004*"would" + 0.004*"one" + 0.004*"plants" + 0.003*"like" + 0.003*"get" + '
#    '0.003*"water" + 0.003*"fish" + 0.003*"also" + 0.003*"time" + 0.003*"use"')]
#
#
# -----------------------
# Label 'IN', 'Cookbooks, Food & Wine'
#  Support is 2228
# 1 TOPIC:
#  [(0,
#    '0.004*"food" + 0.004*"also" + 0.003*"one" + 0.003*"like" + 0.002*"used" + '
#    '0.002*"make" + 0.002*"use" + 0.002*"time" + 0.002*"made" + 0.002*"many"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"new" + 0.002*"may" + 0.002*"time" + '
#    '0.002*"like" + 0.002*"would" + 0.002*"us" + 0.002*"tea" + 0.002*"many"'),
#   (1,
#    '0.005*"food" + 0.004*"also" + 0.003*"one" + 0.003*"like" + 0.003*"coffee" + '
#    '0.003*"used" + 0.003*"make" + 0.003*"use" + 0.002*"made" + 0.002*"protein"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"food" + 0.003*"also" + 0.003*"used" + 0.003*"one" + 0.003*"tea" + '
#    '0.003*"chocolate" + 0.003*"like" + 0.003*"made" + 0.003*"water" + '
#    '0.002*"fruit"'),
#   (1,
#    '0.005*"food" + 0.004*"also" + 0.004*"protein" + 0.003*"one" + 0.003*"fat" + '
#    '0.003*"health" + 0.003*"foods" + 0.003*"diet" + 0.003*"products" + '
#    '0.003*"healthy"'),
#   (2,
#    '0.005*"coffee" + 0.004*"one" + 0.004*"also" + 0.003*"like" + 0.003*"make" + '
#    '0.003*"food" + 0.003*"use" + 0.003*"time" + 0.002*"new" + 0.002*"may"')]
#
#
# -----------------------
# Label 'IN', 'Engineering & Transportation'
#  Support is 99490
# 1 TOPIC:
#  [(0,
#    '0.003*"also" + 0.003*"one" + 0.003*"new" + 0.003*"time" + 0.002*"may" + '
#    '0.002*"use" + 0.002*"used" + 0.002*"us" + 0.002*"system" + 0.002*"data"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"new" + 0.002*"download" + 0.002*"use" + '
#    '0.002*"used" + 0.002*"high" + 0.002*"power" + 0.002*"may" + 0.002*"time"'),
#   (1,
#    '0.003*"also" + 0.003*"new" + 0.003*"one" + 0.003*"time" + 0.002*"service" + '
#    '0.002*"may" + 0.002*"use" + 0.002*"business" + 0.002*"work" + 0.002*"us"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"new" + 0.003*"also" + 0.003*"one" + 0.003*"use" + 0.002*"time" + '
#    '0.002*"us" + 0.002*"products" + 0.002*"work" + 0.002*"service" + '
#    '0.002*"business"'),
#   (1,
#    '0.003*"also" + 0.003*"new" + 0.003*"one" + 0.003*"light" + 0.002*"air" + '
#    '0.002*"time" + 0.002*"first" + 0.002*"university" + 0.002*"used" + '
#    '0.001*"download"'),
#   (2,
#    '0.006*"signal" + 0.006*"media" + 0.005*"data" + 0.005*"may" + 0.004*"gain" '
#    '+ 0.004*"one" + 0.003*"system" + 0.003*"first" + 0.003*"predistortion" + '
#    '0.003*"timing"')]
#
#
# -----------------------
# Label 'IN', 'Literature & Fiction'
#  Support is 190734
# 1 TOPIC:
#  [(0,
#    '0.004*"dating" + 0.003*"one" + 0.003*"new" + 0.002*"free" + 0.002*"like" + '
#    '0.002*"time" + 0.002*"also" + 0.002*"pdf" + 0.002*"online" + 0.002*"first"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"new" + 0.003*"also" + 0.002*"like" + 0.002*"time" + '
#    '0.002*"music" + 0.002*"first" + 0.002*"get" + 0.002*"would" + 0.002*"two"'),
#   (1,
#    '0.008*"dating" + 0.005*"pdf" + 0.004*"short" + 0.004*"file" + '
#    '0.004*"description" + 0.003*"download" + 0.003*"free" + 0.003*"new" + '
#    '0.003*"one" + 0.003*"online"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"new" + 0.003*"time" + 0.003*"would" + '
#    '0.003*"first" + 0.003*"like" + 0.002*"people" + 0.002*"many" + '
#    '0.002*"work"'),
#   (1,
#    '0.012*"pdf" + 0.007*"file" + 0.007*"short" + 0.006*"description" + '
#    '0.003*"boho" + 0.003*"1" + 0.002*"headbands" + 0.002*"edition" + '
#    '0.002*"new" + 0.002*"free"'),
#   (2,
#    '0.011*"dating" + 0.006*"free" + 0.005*"online" + 0.004*"kitchen" + '
#    '0.003*"best" + 0.003*"site" + 0.003*"new" + 0.003*"find" + 0.002*"chair" + '
#    '0.002*"women"')]
#
#
# -----------------------
# Label 'IN', 'Medicine & Health Sciences'
#  Support is 35252
# 1 TOPIC:
#  [(0,
#    '0.003*"may" + 0.003*"also" + 0.003*"one" + 0.002*"patients" + '
#    '0.002*"health" + 0.002*"time" + 0.002*"care" + 0.002*"treatment" + '
#    '0.002*"new" + 0.002*"used"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.004*"health" + 0.003*"also" + 0.003*"may" + 0.003*"people" '
#    '+ 0.002*"care" + 0.002*"time" + 0.002*"new" + 0.002*"like" + 0.002*"help"'),
#   (1,
#    '0.004*"treatment" + 0.004*"may" + 0.004*"patients" + 0.003*"also" + '
#    '0.003*"disease" + 0.003*"study" + 0.003*"used" + 0.002*"one" + '
#    '0.002*"cells" + 0.002*"1"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"time" + 0.003*"may" + 0.003*"like" + '
#    '0.003*"get" + 0.003*"people" + 0.002*"new" + 0.002*"care" + 0.002*"would"'),
#   (1,
#    '0.003*"cells" + 0.003*"study" + 0.003*"also" + 0.003*"used" + '
#    '0.002*"patients" + 0.002*"using" + 0.002*"et" + 0.002*"cancer" + 0.002*"al" '
#    '+ 0.002*"data"'),
#   (2,
#    '0.005*"may" + 0.004*"patients" + 0.004*"health" + 0.004*"also" + '
#    '0.003*"treatment" + 0.003*"blood" + 0.002*"use" + 0.002*"disease" + '
#    '0.002*"one" + 0.002*"used"')]
#
#
# -----------------------
# Label 'IN', 'None'
#  Support is 154246
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"new" + 0.002*"time" + 0.002*"get" + '
#    '0.002*"like" + 0.002*"may" + 0.002*"us" + 0.002*"best" + 0.002*"pdf"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.020*"line" + 0.020*"called" + 0.020*"method" + 0.019*"statically" + '
#    '0.019*"nonstatic" + 0.015*"this" + 0.015*"context" + 0.014*"assuming" + '
#    '0.014*"deprecated" + 0.014*"incompatible"'),
#   (1,
#    '0.004*"one" + 0.003*"also" + 0.003*"new" + 0.003*"time" + 0.003*"like" + '
#    '0.002*"make" + 0.002*"may" + 0.002*"get" + 0.002*"use" + 0.002*"us"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"wall" + 0.004*"wine" + 0.003*"mounted" + 0.003*"dating" + '
#    '0.003*"one" + 0.003*"home" + 0.002*"white" + 0.002*"also" + 0.002*"new" + '
#    '0.002*"free"'),
#   (1,
#    '0.004*"one" + 0.004*"also" + 0.003*"time" + 0.003*"like" + 0.003*"get" + '
#    '0.003*"new" + 0.002*"make" + 0.002*"best" + 0.002*"work" + 0.002*"us"'),
#   (2,
#    '0.007*"pdf" + 0.004*"description" + 0.004*"file" + 0.004*"short" + '
#    '0.003*"may" + 0.003*"download" + 0.003*"new" + 0.003*"one" + '
#    '0.002*"available" + 0.002*"also"')]
#
#
# -----------------------
# Label 'IN', 'Politics & Social Sciences'
#  Support is 134903
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"new" + 0.003*"time" + 0.002*"may" + '
#    '0.002*"people" + 0.002*"use" + 0.002*"get" + 0.002*"us" + '
#    '0.002*"information"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"may" + 0.003*"use" + 0.003*"information" + 0.003*"also" + '
#    '0.003*"one" + 0.003*"time" + 0.002*"us" + 0.002*"business" + 0.002*"new" + '
#    '0.002*"data"'),
#   (1,
#    '0.004*"one" + 0.003*"also" + 0.003*"new" + 0.003*"time" + 0.002*"people" + '
#    '0.002*"like" + 0.002*"first" + 0.002*"work" + 0.002*"many" + 0.002*"us"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"may" + 0.003*"also" + 0.003*"services" + 0.003*"information" + '
#    '0.003*"business" + 0.002*"new" + 0.002*"one" + 0.002*"time" + '
#    '0.002*"students" + 0.002*"work"'),
#   (1,
#    '0.004*"one" + 0.003*"also" + 0.003*"time" + 0.003*"like" + 0.003*"get" + '
#    '0.003*"people" + 0.003*"new" + 0.003*"would" + 0.002*"many" + 0.002*"make"'),
#   (2,
#    '0.007*"data" + 0.005*"information" + 0.005*"may" + 0.004*"use" + 0.004*"st" '
#    '+ 0.003*"ave" + 0.003*"access" + 0.003*"system" + 0.003*"software" + '
#    '0.002*"digital"')]
#
#
# -----------------------
# Label 'IN', 'Science & Math'
#  Support is 12814
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.002*"may" + 0.002*"time" + 0.002*"new" + '
#    '0.002*"two" + 0.002*"water" + 0.002*"used" + 0.002*"use" + 0.002*"species"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"like" + 0.003*"new" + 0.003*"may" + '
#    '0.003*"time" + 0.002*"would" + 0.002*"us" + 0.002*"water" + 0.002*"many"'),
#   (1,
#    '0.003*"data" + 0.003*"also" + 0.003*"using" + 0.003*"1" + 0.002*"two" + '
#    '0.002*"used" + 0.002*"one" + 0.002*"species" + 0.002*"may" + 0.002*"et"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"data" + 0.004*"number" + 0.003*"1" + 0.003*"using" + 0.003*"two" + '
#    '0.003*"one" + 0.003*"study" + 0.003*"used" + 0.003*"also" + '
#    '0.002*"different"'),
#   (1,
#    '0.003*"one" + 0.003*"also" + 0.003*"water" + 0.003*"new" + 0.002*"use" + '
#    '0.002*"time" + 0.002*"may" + 0.002*"many" + 0.002*"plants" + 0.002*"like"'),
#   (2,
#    '0.004*"one" + 0.003*"also" + 0.003*"like" + 0.002*"time" + 0.002*"may" + '
#    '0.002*"two" + 0.002*"would" + 0.002*"download" + 0.002*"water" + '
#    '0.002*"see"')]
#
#
# -----------------------
# Label 'IP', 'Cookbooks, Food & Wine'
#  Support is 1396
# 1 TOPIC:
#  [(0,
#    '0.004*"food" + 0.003*"one" + 0.003*"also" + 0.003*"made" + 0.003*"use" + '
#    '0.002*"make" + 0.002*"like" + 0.002*"product" + 0.002*"used" + 0.002*"new"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"also" + 0.003*"food" + 0.003*"one" + 0.003*"used" + 0.003*"product" '
#    '+ 0.003*"protein" + 0.002*"oil" + 0.002*"use" + 0.002*"like" + '
#    '0.002*"made"'),
#   (1,
#    '0.004*"food" + 0.004*"one" + 0.003*"made" + 0.003*"coffee" + 0.003*"also" + '
#    '0.003*"use" + 0.003*"cheese" + 0.003*"make" + 0.003*"fresh" + 0.002*"tea"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.006*"cheese" + 0.006*"served" + 0.005*"fresh" + 0.005*"sauce" + '
#    '0.004*"chicken" + 0.004*"tea" + 0.003*"topped" + 0.003*"beef" + '
#    '0.003*"meat" + 0.003*"red"'),
#   (1,
#    '0.004*"one" + 0.004*"food" + 0.004*"also" + 0.004*"use" + 0.003*"make" + '
#    '0.003*"like" + 0.003*"made" + 0.003*"great" + 0.003*"time" + '
#    '0.003*"cooking"'),
#   (2,
#    '0.003*"food" + 0.003*"products" + 0.003*"wine" + 0.003*"product" + '
#    '0.003*"flavor" + 0.003*"used" + 0.003*"fruit" + 0.003*"made" + 0.002*"also" '
#    '+ 0.002*"natural"')]
#
#
# -----------------------
# Label 'IP', 'Engineering & Transportation'
#  Support is 41796
# 1 TOPIC:
#  [(0,
#    '0.003*"also" + 0.003*"new" + 0.003*"one" + 0.002*"use" + 0.002*"time" + '
#    '0.002*"us" + 0.002*"service" + 0.002*"quality" + 0.002*"system" + '
#    '0.002*"get"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.004*"also" + 0.003*"new" + 0.003*"service" + 0.003*"get" + '
#    '0.003*"us" + 0.002*"time" + 0.002*"like" + 0.002*"need" + 0.002*"business"'),
#   (1,
#    '0.003*"high" + 0.003*"also" + 0.003*"quality" + 0.003*"new" + 0.003*"one" + '
#    '0.003*"system" + 0.003*"use" + 0.002*"power" + 0.002*"time" + '
#    '0.002*"design"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"service" + 0.003*"new" + 0.003*"us" + 0.003*"also" + '
#    '0.003*"services" + 0.003*"time" + 0.003*"one" + 0.003*"quality" + '
#    '0.003*"best" + 0.003*"products"'),
#   (1,
#    '0.003*"also" + 0.003*"one" + 0.003*"new" + 0.002*"like" + 0.002*"use" + '
#    '0.002*"get" + 0.002*"time" + 0.002*"used" + 0.002*"parts" + 0.002*"us"'),
#   (2,
#    '0.015*"condo" + 0.006*"1" + 0.005*"2" + 0.005*"club" + 0.005*"beach" + '
#    '0.005*"park" + 0.005*"estates" + 0.004*"village" + 0.004*"palm" + '
#    '0.004*"door"')]
#
#
# -----------------------
# Label 'IP', 'Literature & Fiction'
#  Support is 62779
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.004*"new" + 0.002*"also" + 0.002*"like" + 0.002*"free" + '
#    '0.002*"get" + 0.002*"time" + 0.002*"great" + 0.002*"book" + 0.002*"home"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"one" + 0.003*"new" + 0.003*"book" + 0.003*"time" + 0.003*"like" + '
#    '0.002*"also" + 0.002*"get" + 0.002*"would" + 0.002*"us" + 0.002*"two"'),
#   (1,
#    '0.003*"free" + 0.003*"home" + 0.003*"one" + 0.003*"dating" + 0.002*"also" + '
#    '0.002*"new" + 0.002*"room" + 0.002*"great" + 0.002*"find" + 0.002*"get"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.006*"fashion" + 0.005*"magazine" + 0.004*"new" + 0.003*"one" + '
#    '0.003*"book" + 0.003*"also" + 0.003*"like" + 0.003*"get" + 0.003*"time" + '
#    '0.002*"would"'),
#   (1,
#    '0.003*"new" + 0.003*"one" + 0.003*"read" + 0.002*"first" + 0.002*"book" + '
#    '0.002*"time" + 0.002*"world" + 0.002*"two" + 0.002*"also" + 0.002*"years"'),
#   (2,
#    '0.004*"one" + 0.003*"new" + 0.003*"also" + 0.002*"like" + 0.002*"love" + '
#    '0.002*"time" + 0.002*"get" + 0.002*"great" + 0.002*"set" + 0.002*"find"')]
#
#
# -----------------------
# Label 'IP', 'Medicine & Health Sciences'
#  Support is 4352
# 1 TOPIC:
#  [(0,
#    '0.004*"skin" + 0.003*"also" + 0.003*"one" + 0.003*"health" + 0.002*"help" + '
#    '0.002*"body" + 0.002*"use" + 0.002*"time" + 0.002*"new" + 0.002*"may"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"care" + 0.003*"one" + 0.003*"health" + 0.003*"new" + 0.003*"also" + '
#    '0.003*"time" + 0.002*"medical" + 0.002*"us" + 0.002*"help" + '
#    '0.002*"people"'),
#   (1,
#    '0.007*"skin" + 0.004*"body" + 0.004*"also" + 0.003*"use" + 0.003*"one" + '
#    '0.003*"natural" + 0.003*"help" + 0.003*"used" + 0.003*"product" + '
#    '0.002*"treatment"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.012*"skin" + 0.005*"body" + 0.004*"also" + 0.004*"natural" + 0.004*"use" '
#    '+ 0.004*"help" + 0.004*"products" + 0.004*"product" + 0.003*"treatment" + '
#    '0.003*"weight"'),
#   (1,
#    '0.004*"care" + 0.004*"dental" + 0.003*"one" + 0.003*"also" + 0.003*"health" '
#    '+ 0.003*"new" + 0.003*"time" + 0.003*"patients" + 0.003*"help" + '
#    '0.002*"medical"'),
#   (2,
#    '0.003*"one" + 0.003*"also" + 0.003*"download" + 0.003*"may" + '
#    '0.003*"healing" + 0.003*"health" + 0.002*"new" + 0.002*"time" + '
#    '0.002*"book" + 0.002*"people"')]
#
#
# -----------------------
# Label 'IP', 'None'
#  Support is 54581
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.002*"new" + 0.002*"time" + 0.002*"get" + '
#    '0.002*"home" + 0.002*"like" + 0.002*"use" + 0.002*"us" + 0.002*"best"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"new" + 0.003*"also" + 0.003*"time" + 0.003*"get" + '
#    '0.003*"like" + 0.002*"us" + 0.002*"make" + 0.002*"best" + 0.002*"help"'),
#   (1,
#    '0.004*"home" + 0.003*"room" + 0.003*"one" + 0.003*"also" + 0.002*"new" + '
#    '0.002*"area" + 0.002*"great" + 0.002*"features" + 0.002*"2" + '
#    '0.002*"large"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"home" + 0.003*"one" + 0.003*"new" + 0.003*"also" + 0.002*"room" + '
#    '0.002*"time" + 0.002*"2" + 0.002*"well" + 0.002*"area" + 0.002*"like"'),
#   (1,
#    '0.004*"one" + 0.003*"time" + 0.003*"get" + 0.003*"help" + 0.003*"use" + '
#    '0.003*"also" + 0.003*"make" + 0.003*"new" + 0.003*"best" + 0.003*"product"'),
#   (2,
#    '0.003*"one" + 0.003*"home" + 0.003*"also" + 0.003*"us" + 0.002*"get" + '
#    '0.002*"like" + 0.002*"make" + 0.002*"use" + 0.002*"best" + 0.002*"time"')]
#
#
# -----------------------
# Label 'IP', 'Politics & Social Sciences'
#  Support is 21401
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"time" + 0.003*"also" + 0.003*"new" + 0.003*"get" + '
#    '0.003*"business" + 0.003*"us" + 0.002*"help" + 0.002*"make" + '
#    '0.002*"people"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"business" + 0.003*"one" + 0.003*"get" + 0.003*"time" + 0.003*"also" '
#    '+ 0.003*"new" + 0.003*"help" + 0.003*"make" + 0.003*"best" + 0.002*"work"'),
#   (1,
#    '0.004*"one" + 0.003*"time" + 0.003*"also" + 0.003*"us" + 0.002*"new" + '
#    '0.002*"get" + 0.002*"service" + 0.002*"may" + 0.002*"like" + 0.002*"use"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"business" + 0.003*"time" + 0.003*"help" + 0.003*"one" + 0.003*"also" '
#    '+ 0.003*"get" + 0.003*"information" + 0.003*"document" + 0.003*"online" + '
#    '0.002*"translation"'),
#   (1,
#    '0.004*"one" + 0.004*"would" + 0.003*"book" + 0.003*"may" + 0.003*"new" + '
#    '0.003*"time" + 0.003*"also" + 0.002*"people" + 0.002*"like" + 0.002*"life"'),
#   (2,
#    '0.004*"business" + 0.003*"one" + 0.003*"also" + 0.003*"get" + '
#    '0.003*"website" + 0.003*"new" + 0.003*"us" + 0.003*"best" + 0.003*"time" + '
#    '0.003*"services"')]
#
#
# -----------------------
# Label 'IP', 'Science & Math'
#  Support is 1112
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"fishing" + 0.002*"time" + 0.002*"new" + '
#    '0.002*"plants" + 0.002*"water" + 0.002*"use" + 0.002*"many" + 0.002*"like"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"fishing" + 0.004*"plants" + 0.004*"also" + 0.004*"one" + '
#    '0.003*"water" + 0.003*"fish" + 0.002*"great" + 0.002*"use" + 0.002*"best" + '
#    '0.002*"plant"'),
#   (1,
#    '0.004*"book" + 0.003*"one" + 0.002*"new" + 0.002*"time" + 0.002*"also" + '
#    '0.002*"many" + 0.002*"first" + 0.002*"theory" + 0.002*"years" + '
#    '0.002*"students"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.006*"plants" + 0.004*"one" + 0.003*"also" + 0.003*"time" + '
#    '0.003*"succulents" + 0.003*"new" + 0.003*"book" + 0.002*"plant" + '
#    '0.002*"make" + 0.002*"well"'),
#   (1,
#    '0.007*"fishing" + 0.004*"water" + 0.004*"fish" + 0.003*"one" + 0.003*"also" '
#    '+ 0.003*"use" + 0.002*"new" + 0.002*"great" + 0.002*"time" + 0.002*"well"'),
#   (2,
#    '0.003*"one" + 0.003*"also" + 0.002*"control" + 0.002*"book" + 0.002*"many" '
#    '+ 0.002*"new" + 0.002*"time" + 0.002*"first" + 0.002*"theory" + '
#    '0.002*"years"')]
#
#
# -----------------------
# Label 'LY', 'Literature & Fiction'
#  Support is 1908
# 1 TOPIC:
#  [(0,
#    '0.007*"😳" + 0.004*"download" + 0.004*"one" + 0.004*"like" + 0.004*"love" + '
#    '0.003*"would" + 0.003*"time" + 0.003*"know" + 0.002*"im" + 0.002*"get"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.006*"love" + 0.005*"like" + 0.005*"one" + 0.004*"know" + 0.004*"im" + '
#    '0.004*"time" + 0.003*"get" + 0.003*"see" + 0.003*"life" + 0.003*"never"'),
#   (1,
#    '0.017*"😳" + 0.010*"download" + 0.004*"viagra" + 0.003*"one" + '
#    '0.003*"discrete" + 0.003*"mathematics" + 0.002*"would" + 0.002*"cialis" + '
#    '0.002*"online" + 0.002*"like"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.006*"download" + 0.005*"one" + 0.005*"love" + 0.004*"like" + 0.003*"time" '
#    '+ 0.003*"know" + 0.003*"life" + 0.003*"get" + 0.003*"would" + 0.003*"see"'),
#   (1,
#    '0.037*"😳" + 0.005*"im" + 0.005*"4040" + 0.005*"like" + 0.004*"love" + '
#    '0.003*"one" + 0.003*"know" + 0.003*"would" + 0.002*"well" + 0.002*"lyrics"'),
#   (2,
#    '0.008*"viagra" + 0.004*"cialis" + 0.004*"download" + 0.004*"state" + '
#    '0.003*"belgium" + 0.003*"archives" + 0.003*"one" + 0.002*"said" + '
#    '0.002*"cemiterio" + 0.002*"would"')]
#
#
# -----------------------
# Label 'LY', 'Politics & Social Sciences'
#  Support is 28
# 1 TOPIC:
#  [(0,
#    '0.034*"archives" + 0.034*"state" + 0.034*"belgium" + 0.008*"league" + '
#    '0.007*"cup" + 0.006*"whiteboard" + 0.005*"round" + 0.005*"mortgage" + '
#    '0.005*"software" + 0.004*"may"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.083*"archives" + 0.082*"state" + 0.082*"belgium" + 0.018*"league" + '
#    '0.016*"cup" + 0.013*"round" + 0.010*"trophy" + 0.009*"group" + 0.009*"fa" + '
#    '0.006*"efl"'),
#   (1,
#    '0.010*"whiteboard" + 0.009*"mortgage" + 0.008*"software" + 0.007*"may" + '
#    '0.005*"use" + 0.004*"data" + 0.003*"information" + 0.003*"new" + '
#    '0.003*"punk" + 0.003*"agreement"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.102*"archives" + 0.102*"state" + 0.101*"belgium" + 0.022*"league" + '
#    '0.019*"cup" + 0.016*"round" + 0.012*"trophy" + 0.012*"fa" + 0.011*"group" + '
#    '0.008*"efl"'),
#   (1,
#    '0.006*"punk" + 0.006*"new" + 0.005*"2013" + 0.005*"me" + 0.005*"music" + '
#    '0.005*"2014" + 0.004*"2016" + 0.004*"2015" + 0.004*"2012" + 0.004*"1"'),
#   (2,
#    '0.016*"whiteboard" + 0.014*"mortgage" + 0.012*"software" + 0.008*"may" + '
#    '0.007*"use" + 0.006*"data" + 0.005*"information" + 0.005*"agreement" + '
#    '0.004*"services" + 0.004*"party"')]
#
#
# -----------------------
# Label 'NA', 'Cookbooks, Food & Wine'
#  Support is 427
# 1 TOPIC:
#  [(0,
#    '0.005*"one" + 0.004*"like" + 0.003*"time" + 0.003*"also" + 0.003*"make" + '
#    '0.003*"food" + 0.003*"get" + 0.003*"good" + 0.003*"would" + 0.002*"made"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"like" + 0.005*"one" + 0.004*"time" + 0.004*"make" + 0.004*"get" + '
#    '0.003*"food" + 0.003*"good" + 0.003*"also" + 0.003*"would" + 0.003*"made"'),
#   (1,
#    '0.005*"casino" + 0.004*"new" + 0.004*"shall" + 0.003*"year" + 0.003*"may" + '
#    '0.003*"per" + 0.003*"gaming" + 0.003*"also" + 0.002*"one" + '
#    '0.002*"fulltime"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.005*"one" + 0.004*"like" + 0.004*"year" + 0.003*"per" + 0.003*"beans" + '
#    '0.003*"time" + 0.003*"green" + 0.003*"fulltime" + 0.003*"get" + '
#    '0.003*"would"'),
#   (1,
#    '0.008*"casino" + 0.006*"shall" + 0.005*"gaming" + 0.003*"may" + '
#    '0.003*"internet" + 0.003*"division" + 0.003*"new" + 0.003*"coffee" + '
#    '0.003*"licensee" + 0.003*"one"'),
#   (2,
#    '0.005*"like" + 0.005*"one" + 0.004*"food" + 0.004*"make" + 0.004*"time" + '
#    '0.004*"also" + 0.003*"get" + 0.003*"good" + 0.003*"would" + 0.003*"made"')]
#
#
# -----------------------
# Label 'NA', 'Engineering & Transportation'
#  Support is 17251
# 1 TOPIC:
#  [(0,
#    '0.004*"new" + 0.003*"one" + 0.003*"also" + 0.002*"said" + 0.002*"would" + '
#    '0.002*"time" + 0.002*"first" + 0.002*"us" + 0.002*"like" + 0.002*"get"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"new" + 0.003*"also" + 0.003*"time" + 0.003*"would" + '
#    '0.003*"like" + 0.002*"get" + 0.002*"us" + 0.002*"first" + 0.002*"two"'),
#   (1,
#    '0.004*"new" + 0.004*"said" + 0.003*"also" + 0.003*"one" + 0.003*"us" + '
#    '0.002*"first" + 0.002*"energy" + 0.002*"company" + 0.002*"would" + '
#    '0.002*"business"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"new" + 0.003*"company" + 0.003*"said" + 0.003*"also" + '
#    '0.002*"energy" + 0.002*"us" + 0.002*"one" + 0.002*"project" + 0.002*"may" + '
#    '0.002*"million"'),
#   (1,
#    '0.002*"first" + 0.002*"new" + 0.002*"one" + 0.002*"also" + 0.002*"would" + '
#    '0.002*"two" + 0.002*"time" + 0.002*"world" + 0.001*"like" + 0.001*"–"'),
#   (2,
#    '0.005*"new" + 0.004*"one" + 0.003*"also" + 0.003*"time" + 0.003*"said" + '
#    '0.003*"would" + 0.002*"like" + 0.002*"first" + 0.002*"get" + 0.002*"us"')]
#
#
# -----------------------
# Label 'NA', 'Literature & Fiction'
#  Support is 113824
# 1 TOPIC:
#  [(0,
#    '0.005*"one" + 0.004*"like" + 0.003*"time" + 0.003*"new" + 0.003*"would" + '
#    '0.003*"get" + 0.002*"first" + 0.002*"also" + 0.002*"back" + 0.002*"people"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"born" + 0.003*"england" + 0.003*"listed" + 0.003*"halstead" + '
#    '0.003*"aged" + 0.003*"new" + 0.003*"yorkshire" + 0.003*"census" + '
#    '0.002*"april" + 0.002*"son"'),
#   (1,
#    '0.005*"one" + 0.005*"like" + 0.004*"time" + 0.003*"would" + 0.003*"get" + '
#    '0.003*"new" + 0.003*"also" + 0.003*"people" + 0.003*"back" + 0.003*"first"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.005*"one" + 0.004*"time" + 0.004*"like" + 0.004*"fashion" + 0.003*"would" '
#    '+ 0.003*"magazine" + 0.003*"get" + 0.003*"new" + 0.003*"people" + '
#    '0.003*"first"'),
#   (1,
#    '0.005*"one" + 0.005*"would" + 0.004*"like" + 0.004*"time" + 0.003*"could" + '
#    '0.003*"get" + 0.003*"know" + 0.003*"back" + 0.003*"it" + 0.002*"see"'),
#   (2,
#    '0.004*"new" + 0.003*"one" + 0.003*"also" + 0.002*"first" + 0.002*"time" + '
#    '0.002*"said" + 0.002*"two" + 0.002*"year" + 0.001*"like" + 0.001*"may"')]
#
#
# -----------------------
# Label 'NA', 'Medicine & Health Sciences'
#  Support is 5983
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"new" + 0.003*"also" + 0.003*"health" + 0.003*"said" + '
#    '0.003*"time" + 0.003*"people" + 0.002*"would" + 0.002*"may" + 0.002*"like"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"health" + 0.004*"patients" + 0.004*"new" + 0.004*"said" + '
#    '0.004*"cancer" + 0.003*"also" + 0.003*"research" + 0.003*"medical" + '
#    '0.002*"one" + 0.002*"study"'),
#   (1,
#    '0.005*"one" + 0.004*"time" + 0.004*"like" + 0.003*"would" + 0.003*"people" '
#    '+ 0.003*"get" + 0.003*"also" + 0.003*"may" + 0.002*"new" + 0.002*"know"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.006*"health" + 0.004*"also" + 0.003*"said" + 0.003*"new" + 0.003*"care" + '
#    '0.003*"one" + 0.003*"may" + 0.003*"medical" + 0.003*"people" + '
#    '0.003*"research"'),
#   (1,
#    '0.005*"patients" + 0.005*"cancer" + 0.004*"new" + 0.004*"study" + '
#    '0.003*"drug" + 0.003*"treatment" + 0.003*"may" + 0.003*"also" + '
#    '0.003*"said" + 0.003*"cells"'),
#   (2,
#    '0.005*"one" + 0.004*"would" + 0.004*"like" + 0.004*"time" + 0.003*"get" + '
#    '0.003*"people" + 0.003*"also" + 0.003*"new" + 0.003*"know" + 0.003*"said"')]
#
#
# -----------------------
# Label 'NA', 'None'
#  Support is 41241
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"time" + 0.003*"new" + 0.003*"like" + '
#    '0.003*"get" + 0.002*"would" + 0.002*"first" + 0.002*"said" + '
#    '0.002*"people"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"time" + 0.003*"get" + 0.003*"new" + 0.003*"like" + '
#    '0.003*"also" + 0.002*"would" + 0.002*"first" + 0.002*"available" + '
#    '0.002*"us"'),
#   (1,
#    '0.004*"one" + 0.004*"a" + 0.003*"href" + 0.003*"new" + 0.003*"also" + '
#    '0.003*"like" + 0.003*"time" + 0.003*"would" + 0.002*"first" + 0.002*"get"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"time" + 0.003*"new" + 0.003*"would" + '
#    '0.002*"like" + 0.002*"first" + 0.002*"get" + 0.002*"people" + 0.002*"said"'),
#   (1,
#    '0.003*"first" + 0.002*"two" + 0.002*"new" + 0.002*"one" + 0.002*"january" + '
#    '0.002*"county" + 0.002*"florida" + 0.002*"said" + 0.002*"also" + 0.002*"2"'),
#   (2,
#    '0.005*"one" + 0.004*"like" + 0.003*"would" + 0.003*"time" + 0.003*"also" + '
#    '0.003*"new" + 0.003*"get" + 0.002*"said" + 0.002*"first" + 0.002*"us"')]
#
#
# -----------------------
# Label 'NA', 'Politics & Social Sciences'
#  Support is 93575
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.003*"said" + 0.003*"would" + 0.003*"people" + 0.003*"new" + '
#    '0.003*"also" + 0.003*"us" + 0.002*"time" + 0.002*"like" + 0.002*"first"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.006*"magazine" + 0.005*"fashion" + 0.003*"said" + 0.003*"new" + '
#    '0.003*"also" + 0.002*"one" + 0.002*"cover" + 0.002*"state" + 0.002*"us" + '
#    '0.002*"model"'),
#   (1,
#    '0.004*"one" + 0.004*"would" + 0.003*"people" + 0.003*"like" + 0.003*"new" + '
#    '0.003*"also" + 0.003*"time" + 0.003*"said" + 0.003*"us" + 0.002*"get"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.004*"said" + 0.003*"people" + 0.003*"like" + 0.003*"time" + '
#    '0.003*"new" + 0.003*"would" + 0.003*"also" + 0.003*"get" + 0.003*"us"'),
#   (1,
#    '0.003*"one" + 0.003*"also" + 0.003*"said" + 0.003*"new" + 0.003*"would" + '
#    '0.002*"people" + 0.002*"us" + 0.002*"may" + 0.002*"time" + 0.002*"first"'),
#   (2,
#    '0.004*"said" + 0.003*"new" + 0.003*"also" + 0.002*"would" + 0.002*"one" + '
#    '0.002*"us" + 0.002*"may" + 0.002*"state" + 0.002*"two" + '
#    '0.002*"government"')]
#
#
# -----------------------
# Label 'NA', 'Science & Math'
#  Support is 3602
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"new" + 0.003*"time" + 0.002*"said" + '
#    '0.002*"would" + 0.002*"water" + 0.002*"like" + 0.002*"two" + 0.002*"first"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"water" + 0.003*"new" + 0.003*"also" + 0.003*"said" + 0.003*"one" + '
#    '0.002*"research" + 0.002*"years" + 0.002*"would" + 0.002*"time" + '
#    '0.002*"us"'),
#   (1,
#    '0.005*"one" + 0.003*"time" + 0.003*"like" + 0.003*"also" + 0.003*"would" + '
#    '0.003*"get" + 0.002*"new" + 0.002*"two" + 0.002*"see" + 0.002*"first"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.005*"one" + 0.003*"time" + 0.003*"fish" + 0.003*"also" + 0.003*"like" + '
#    '0.003*"get" + 0.002*"see" + 0.002*"would" + 0.002*"year" + 0.002*"us"'),
#   (1,
#    '0.003*"new" + 0.003*"said" + 0.003*"also" + 0.003*"one" + 0.003*"research" '
#    '+ 0.002*"would" + 0.002*"time" + 0.002*"years" + 0.002*"could" + '
#    '0.002*"two"'),
#   (2,
#    '0.003*"one" + 0.003*"also" + 0.002*"new" + 0.002*"would" + 0.002*"like" + '
#    '0.002*"may" + 0.002*"time" + 0.002*"bees" + 0.002*"get" + 0.002*"people"')]
#
#
# -----------------------
# Label 'None', 'Cookbooks, Food & Wine'
#  Support is 77
# 1 TOPIC:
#  [(0,
#    '0.005*"buttermilk" + 0.004*"one" + 0.003*"chicken" + 0.002*"like" + '
#    '0.002*"make" + 0.002*"also" + 0.002*"it" + 0.002*"served" + 0.002*"us" + '
#    '0.002*"would"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"like" + 0.003*"health" + 0.003*"cheese" + '
#    '0.002*"insurance" + 0.002*"also" + 0.002*"served" + 0.002*"it" + 0.002*"us" '
#    '+ 0.002*"get"'),
#   (1,
#    '0.010*"buttermilk" + 0.004*"one" + 0.003*"chicken" + 0.003*"kitchen" + '
#    '0.003*"make" + 0.003*"food" + 0.002*"mr" + 0.002*"also" + 0.002*"would" + '
#    '0.002*"it"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.015*"buttermilk" + 0.005*"kitchen" + 0.005*"chicken" + 0.005*"served" + '
#    '0.004*"sauce" + 0.003*"cream" + 0.003*"one" + 0.003*"like" + 0.003*"beef" + '
#    '0.003*"make"'),
#   (1,
#    '0.005*"one" + 0.003*"food" + 0.003*"it" + 0.003*"them" + 0.003*"us" + '
#    '0.002*"make" + 0.002*"like" + 0.002*"love" + 0.002*"many" + '
#    '0.002*"chicken"'),
#   (2,
#    '0.004*"health" + 0.004*"insurance" + 0.003*"said" + 0.003*"one" + '
#    '0.002*"mr" + 0.002*"would" + 0.002*"get" + 0.002*"us" + 0.002*"also" + '
#    '0.002*"oil"')]
#
#
# -----------------------
# Label 'None', 'Engineering & Transportation'
#  Support is 1461
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"would" + 0.003*"get" + 0.003*"new" + '
#    '0.003*"time" + 0.003*"like" + 0.002*"use" + 0.002*"make" + 0.002*"need"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"time" + 0.003*"get" + 0.003*"new" + '
#    '0.003*"like" + 0.002*"use" + 0.002*"would" + 0.002*"need" + 0.002*"well"'),
#   (1,
#    '0.004*"would" + 0.004*"one" + 0.003*"car" + 0.003*"also" + 0.003*"new" + '
#    '0.003*"get" + 0.002*"like" + 0.002*"insurance" + 0.002*"time" + '
#    '0.002*"make"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"get" + 0.003*"time" + 0.003*"also" + 0.003*"like" + '
#    '0.003*"car" + 0.003*"new" + 0.003*"would" + 0.002*"make" + 0.002*"may"'),
#   (1,
#    '0.004*"would" + 0.003*"also" + 0.003*"one" + 0.002*"new" + 0.002*"get" + '
#    '0.002*"time" + 0.002*"well" + 0.002*"need" + 0.002*"business" + '
#    '0.002*"like"'),
#   (2,
#    '0.004*"new" + 0.003*"one" + 0.003*"work" + 0.003*"like" + 0.003*"home" + '
#    '0.003*"also" + 0.003*"would" + 0.002*"use" + 0.002*"design" + 0.002*"get"')]
#
#
# -----------------------
# Label 'None', 'Literature & Fiction'
#  Support is 11857
# 1 TOPIC:
#  [(0,
#    '0.012*"dating" + 0.004*"online" + 0.003*"site" + 0.003*"one" + 0.003*"like" '
#    '+ 0.003*"free" + 0.003*"new" + 0.003*"get" + 0.002*"best" + 0.002*"time"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.006*"dating" + 0.006*"j" + 0.005*"viagra" + 0.003*"without" + '
#    '0.003*"cialis" + 0.002*"online" + 0.002*"rencontre" + 0.002*"way" + '
#    '0.002*"site" + 0.002*"de"'),
#   (1,
#    '0.009*"dating" + 0.005*"like" + 0.004*"one" + 0.004*"get" + 0.004*"site" + '
#    '0.003*"time" + 0.003*"dahyun" + 0.003*"new" + 0.003*"know" + '
#    '0.003*"online"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.005*"like" + 0.005*"one" + 0.004*"time" + 0.004*"said" + 0.003*"would" + '
#    '0.003*"site" + 0.003*"really" + 0.003*"get" + 0.003*"also" + 0.003*"know"'),
#   (1,
#    '0.038*"dating" + 0.011*"online" + 0.008*"free" + 0.006*"site" + '
#    '0.005*"sites" + 0.004*"best" + 0.004*"singles" + 0.004*"women" + '
#    '0.003*"single" + 0.003*"find"'),
#   (2,
#    '0.004*"one" + 0.004*"like" + 0.003*"get" + 0.003*"new" + 0.003*"time" + '
#    '0.003*"would" + 0.003*"looking" + 0.002*"love" + 0.002*"said" + '
#    '0.002*"want"')]
#
#
# -----------------------
# Label 'None', 'Medicine & Health Sciences'
#  Support is 176
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"time" + 0.002*"would" + 0.002*"may" + '
#    '0.002*"like" + 0.002*"get" + 0.002*"new" + 0.002*"shop" + 0.002*"people"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"shop" + 0.004*"linterpretazione" + 0.003*"della" + 0.003*"musica" + '
#    '0.003*"also" + 0.003*"dei" + 0.003*"may" + 0.003*"one" + 0.002*"life" + '
#    '0.002*"time"'),
#   (1,
#    '0.004*"one" + 0.003*"like" + 0.003*"get" + 0.003*"would" + 0.003*"also" + '
#    '0.003*"time" + 0.002*"may" + 0.002*"new" + 0.002*"people" + 0.002*"years"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"time" + 0.003*"would" + 0.003*"like" + 0.003*"get" + '
#    '0.003*"also" + 0.003*"health" + 0.003*"people" + 0.003*"care" + '
#    '0.002*"may"'),
#   (1,
#    '0.007*"shop" + 0.006*"linterpretazione" + 0.005*"della" + 0.005*"musica" + '
#    '0.004*"dei" + 0.003*"secoli" + 0.003*"life" + 0.003*"xvii" + 0.003*"myc" + '
#    '0.003*"new"'),
#   (2,
#    '0.003*"one" + 0.003*"time" + 0.003*"also" + 0.002*"would" + 0.002*"may" + '
#    '0.002*"like" + 0.002*"get" + 0.002*"new" + 0.002*"help" + 0.002*"make"')]
#
#
# -----------------------
# Label 'None', 'None'
#  Support is 4662
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.003*"like" + 0.003*"time" + 0.003*"get" + 0.003*"also" + '
#    '0.003*"dating" + 0.003*"would" + 0.003*"new" + 0.002*"make" + 0.002*"best"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"one" + 0.004*"like" + 0.003*"time" + 0.003*"get" + 0.003*"would" + '
#    '0.003*"also" + 0.003*"new" + 0.003*"make" + 0.002*"people" + 0.002*"us"'),
#   (1,
#    '0.006*"dating" + 0.004*"one" + 0.003*"home" + 0.003*"new" + 0.003*"best" + '
#    '0.003*"like" + 0.003*"also" + 0.003*"would" + 0.002*"site" + 0.002*"get"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.006*"dating" + 0.004*"one" + 0.003*"time" + 0.003*"like" + 0.003*"get" + '
#    '0.003*"new" + 0.003*"best" + 0.003*"also" + 0.003*"would" + 0.003*"free"'),
#   (1,
#    '0.004*"download" + 0.003*"one" + 0.003*"like" + 0.003*"also" + 0.003*"site" '
#    '+ 0.003*"affiliate" + 0.003*"time" + 0.002*"wallpaper" + 0.002*"marketing" '
# ...
#    '+ 0.003*"served" + 0.003*"sauce" + 0.003*"product" + 0.003*"organic" + '
#    '0.003*"chocolate"'),
#   (1,
#    '0.003*"food" + 0.003*"also" + 0.003*"one" + 0.003*"use" + 0.003*"time" + '
#    '0.003*"make" + 0.003*"cooking" + 0.003*"easy" + 0.002*"like" + '
#    '0.002*"steel"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"one" + 0.003*"also" + 0.003*"use" + 0.003*"new" + 0.003*"food" + '
#    '0.003*"time" + 0.003*"made" + 0.003*"make" + 0.002*"like" + 0.002*"steel"'),
#   (1,
#    '0.006*"cheese" + 0.006*"served" + 0.006*"fresh" + 0.006*"sauce" + '
#    '0.005*"chicken" + 0.003*"red" + 0.003*"topped" + 0.003*"wine" + '
#    '0.003*"made" + 0.003*"one"'),
#   (2,
#    '0.005*"food" + 0.004*"product" + 0.004*"tea" + 0.004*"used" + 0.003*"also" '
#    '+ 0.003*"use" + 0.003*"made" + 0.003*"products" + 0.003*"protein" + '
#    '0.003*"one"')]
#
#
# -----------------------
# Label 'ds', 'Engineering & Transportation'
#  Support is 38576
# 1 TOPIC:
#  [(0,
#    '0.003*"new" + 0.003*"one" + 0.003*"also" + 0.002*"quality" + 0.002*"use" + '
#    '0.002*"time" + 0.002*"us" + 0.002*"service" + 0.002*"get" + 0.002*"best"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"us" + 0.003*"also" + 0.002*"time" + 0.002*"get" + '
#    '0.002*"first" + 0.002*"like" + 0.002*"part" + 0.002*"would" + 0.002*"may"'),
#   (1,
#    '0.003*"new" + 0.003*"also" + 0.003*"one" + 0.003*"service" + '
#    '0.003*"quality" + 0.002*"us" + 0.002*"use" + 0.002*"time" + 0.002*"get" + '
#    '0.002*"best"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"us" + 0.003*"new" + 0.003*"also" + 0.003*"service" + '
#    '0.003*"car" + 0.003*"time" + 0.003*"home" + 0.003*"get" + 0.002*"best"'),
#   (1,
#    '0.004*"ebook" + 0.004*"florida" + 0.003*"new" + 0.003*"нейтронные" + '
#    '0.003*"one" + 0.002*"звезды" + 0.002*"voter" + 0.002*"number" + 0.002*"use" '
#    '+ 0.002*"helicopter"'),
#   (2,
#    '0.003*"use" + 0.003*"new" + 0.003*"also" + 0.003*"high" + 0.003*"one" + '
#    '0.002*"quality" + 0.002*"system" + 0.002*"time" + 0.002*"power" + '
#    '0.002*"used"')]
#
#
# -----------------------
# Label 'ds', 'Literature & Fiction'
#  Support is 58348
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.003*"new" + 0.003*"also" + 0.002*"time" + 0.002*"like" + '
#    '0.002*"great" + 0.002*"book" + 0.002*"get" + 0.002*"make" + 0.002*"first"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"new" + 0.003*"home" + 0.002*"also" + 0.002*"great" + '
#    '0.002*"room" + 0.002*"two" + 0.002*"first" + 0.002*"perfect" + '
#    '0.002*"back"'),
#   (1,
#    '0.004*"one" + 0.003*"like" + 0.003*"time" + 0.003*"new" + 0.003*"get" + '
#    '0.002*"love" + 0.002*"life" + 0.002*"book" + 0.002*"find" + 0.002*"also"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"new" + 0.002*"free" + 0.002*"book" + 0.002*"2" + '
#    '0.002*"time" + 0.002*"like" + 0.002*"also" + 0.002*"first" + 0.002*"made"'),
#   (1,
#    '0.004*"home" + 0.003*"one" + 0.003*"great" + 0.003*"new" + 0.003*"also" + '
#    '0.003*"room" + 0.002*"us" + 0.002*"time" + 0.002*"best" + 0.002*"well"'),
#   (2,
#    '0.004*"one" + 0.003*"new" + 0.003*"book" + 0.003*"like" + 0.003*"also" + '
#    '0.002*"life" + 0.002*"love" + 0.002*"time" + 0.002*"get" + 0.002*"world"')]
#
#
# -----------------------
# Label 'ds', 'Medicine & Health Sciences'
#  Support is 3750
# 1 TOPIC:
#  [(0,
#    '0.004*"skin" + 0.003*"also" + 0.003*"one" + 0.002*"health" + 0.002*"use" + '
#    '0.002*"help" + 0.002*"time" + 0.002*"body" + 0.002*"new" + 0.002*"may"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.009*"skin" + 0.004*"body" + 0.004*"also" + 0.003*"use" + 0.003*"natural" '
#    '+ 0.003*"used" + 0.003*"product" + 0.003*"products" + 0.003*"help" + '
#    '0.003*"one"'),
#   (1,
#    '0.003*"one" + 0.003*"also" + 0.003*"health" + 0.003*"new" + 0.003*"time" + '
#    '0.002*"help" + 0.002*"care" + 0.002*"medical" + 0.002*"us" + 0.002*"get"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.011*"skin" + 0.005*"body" + 0.004*"also" + 0.004*"natural" + 0.003*"use" '
#    '+ 0.003*"products" + 0.003*"treatment" + 0.003*"product" + 0.003*"help" + '
#    '0.003*"one"'),
#   (1,
#    '0.003*"also" + 0.003*"one" + 0.002*"course" + 0.002*"online" + 0.002*"use" '
#    '+ 0.002*"new" + 0.002*"read" + 0.002*"patients" + 0.002*"well" + '
#    '0.002*"like"'),
#   (2,
#    '0.004*"one" + 0.003*"health" + 0.003*"also" + 0.003*"time" + 0.003*"new" + '
#    '0.002*"care" + 0.002*"may" + 0.002*"people" + 0.002*"us" + 0.002*"help"')]
#
#
# -----------------------
# Label 'ds', 'None'
#  Support is 49749
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"new" + 0.003*"time" + 0.003*"home" + '
#    '0.002*"get" + 0.002*"make" + 0.002*"us" + 0.002*"like" + 0.002*"best"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"also" + 0.003*"one" + 0.002*"time" + 0.002*"new" + 0.002*"use" + '
#    '0.002*"like" + 0.002*"great" + 0.002*"get" + 0.002*"home" + 0.002*"may"'),
#   (1,
#    '0.003*"one" + 0.003*"new" + 0.003*"us" + 0.003*"also" + 0.003*"home" + '
#    '0.003*"get" + 0.003*"time" + 0.002*"like" + 0.002*"make" + 0.002*"best"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"get" + 0.003*"time" + 0.003*"also" + 0.003*"one" + 0.003*"new" + '
#    '0.003*"free" + 0.002*"5" + 0.002*"make" + 0.002*"best" + 0.002*"use"'),
#   (1,
#    '0.003*"one" + 0.003*"also" + 0.003*"us" + 0.002*"use" + 0.002*"best" + '
#    '0.002*"hair" + 0.002*"like" + 0.002*"make" + 0.002*"replica" + '
#    '0.002*"time"'),
#   (2,
#    '0.005*"home" + 0.004*"room" + 0.004*"one" + 0.003*"new" + 0.003*"great" + '
#    '0.003*"also" + 0.002*"area" + 0.002*"best" + 0.002*"time" + 0.002*"like"')]
#
#
# -----------------------
# Label 'ds', 'Politics & Social Sciences'
#  Support is 18344
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"time" + 0.003*"new" + 0.003*"get" + '
#    '0.003*"us" + 0.003*"business" + 0.002*"help" + 0.002*"like" + 0.002*"work"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"business" + 0.004*"get" + 0.003*"time" + 0.003*"also" + 0.003*"one" '
#    '+ 0.003*"help" + 0.003*"services" + 0.003*"service" + 0.003*"make" + '
#    '0.003*"need"'),
#   (1,
#    '0.004*"one" + 0.003*"book" + 0.003*"new" + 0.003*"time" + 0.003*"life" + '
#    '0.002*"also" + 0.002*"people" + 0.002*"would" + 0.002*"like" + 0.002*"us"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"business" + 0.004*"one" + 0.003*"time" + 0.003*"new" + 0.003*"get" + '
#    '0.003*"also" + 0.003*"help" + 0.003*"us" + 0.003*"book" + 0.003*"make"'),
#   (1,
#    '0.004*"one" + 0.002*"good" + 0.002*"leather" + 0.002*"complete" + '
#    '0.002*"first" + 0.002*"original" + 0.002*"two" + 0.002*"symbol" + '
#    '0.002*"german" + 0.002*"helmet"'),
#   (2,
#    '0.004*"get" + 0.003*"one" + 0.003*"time" + 0.003*"document" + 0.003*"also" '
#    '+ 0.003*"translation" + 0.003*"home" + 0.003*"brazilian" + 0.003*"service" '
#    '+ 0.003*"best"')]
#
#
# -----------------------
# Label 'ds', 'Science & Math'
#  Support is 1031
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"fishing" + 0.002*"time" + '
#    '0.002*"plants" + 0.002*"new" + 0.002*"use" + 0.002*"water" + 0.002*"book" + '
#    '0.002*"many"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.005*"fishing" + 0.003*"one" + 0.003*"also" + 0.003*"book" + 0.002*"new" + '
#    '0.002*"many" + 0.002*"fish" + 0.002*"time" + 0.002*"great" + 0.002*"use"'),
#   (1,
#    '0.004*"plants" + 0.004*"also" + 0.003*"one" + 0.003*"time" + 0.002*"water" '
#    '+ 0.002*"like" + 0.002*"us" + 0.002*"use" + 0.002*"new" + 0.002*"make"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"plants" + 0.003*"also" + 0.003*"one" + 0.003*"water" + 0.003*"book" '
#    '+ 0.003*"succulents" + 0.002*"new" + 0.002*"time" + 0.002*"make" + '
#    '0.002*"fish"'),
#   (1,
#    '0.005*"plant" + 0.004*"one" + 0.004*"plants" + 0.003*"also" + 0.003*"soil" '
#    '+ 0.002*"new" + 0.002*"water" + 0.002*"well" + 0.002*"flowers" + '
#    '0.002*"great"'),
#   (2,
#    '0.006*"fishing" + 0.003*"one" + 0.003*"time" + 0.003*"also" + 0.002*"book" '
#    '+ 0.002*"new" + 0.002*"many" + 0.002*"like" + 0.002*"use" + 0.002*"first"')]
#
#
# -----------------------
# Label 'dtp', 'Cookbooks, Food & Wine'
#  Support is 612
# 1 TOPIC:
#  [(0,
#    '0.004*"food" + 0.004*"also" + 0.003*"used" + 0.003*"one" + 0.002*"products" '
#    '+ 0.002*"tea" + 0.002*"made" + 0.002*"product" + 0.002*"coffee" + '
#    '0.002*"many"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"also" + 0.004*"food" + 0.003*"coffee" + 0.003*"chocolate" + '
#    '0.003*"wine" + 0.003*"one" + 0.003*"made" + 0.003*"used" + 0.002*"fruit" + '
#    '0.002*"quality"'),
#   (1,
#    '0.005*"food" + 0.005*"tea" + 0.005*"used" + 0.003*"also" + 0.003*"product" '
#    '+ 0.003*"one" + 0.002*"products" + 0.002*"high" + 0.002*"many" + '
#    '0.002*"like"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"used" + 0.003*"cheese" + 0.003*"also" + 0.003*"fruit" + '
#    '0.003*"flavor" + 0.003*"foods" + 0.003*"natural" + 0.003*"food" + '
#    '0.003*"coffee" + 0.002*"product"'),
#   (1,
#    '0.006*"used" + 0.006*"food" + 0.005*"also" + 0.004*"oil" + 0.004*"products" '
#    '+ 0.004*"product" + 0.003*"protein" + 0.003*"milk" + 0.003*"tea" + '
#    '0.003*"fruit"'),
#   (2,
#    '0.004*"food" + 0.004*"chocolate" + 0.004*"one" + 0.003*"also" + 0.003*"tea" '
#    '+ 0.002*"make" + 0.002*"like" + 0.002*"new" + 0.002*"many" + 0.002*"us"')]
#
#
# -----------------------
# Label 'dtp', 'Engineering & Transportation'
#  Support is 48529
# 1 TOPIC:
#  [(0,
#    '0.003*"new" + 0.003*"also" + 0.003*"one" + 0.002*"time" + 0.002*"service" + '
#    '0.002*"use" + 0.002*"system" + 0.002*"work" + 0.002*"used" + '
#    '0.002*"services"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"new" + 0.003*"also" + 0.003*"services" + 0.003*"one" + '
#    '0.002*"service" + 0.002*"us" + 0.002*"work" + 0.002*"business" + '
#    '0.002*"time" + 0.002*"company"'),
#   (1,
#    '0.003*"design" + 0.003*"new" + 0.003*"also" + 0.002*"one" + 0.002*"high" + '
#    '0.002*"used" + 0.002*"use" + 0.002*"system" + 0.002*"quality" + '
#    '0.002*"products"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.005*"new" + 0.003*"one" + 0.003*"also" + 0.002*"time" + 0.002*"system" + '
#    '0.002*"world" + 0.002*"us" + 0.002*"would" + 0.002*"energy" + 0.002*"–"'),
#   (1,
#    '0.003*"new" + 0.003*"also" + 0.002*"high" + 0.002*"one" + 0.002*"products" '
#    '+ 0.002*"use" + 0.002*"business" + 0.002*"time" + 0.002*"us" + '
#    '0.002*"work"'),
#   (2,
#    '0.004*"also" + 0.003*"design" + 0.003*"new" + 0.003*"service" + '
#    '0.003*"system" + 0.002*"one" + 0.002*"use" + 0.002*"water" + 0.002*"used" + '
#    '0.002*"quality"')]
#
#
# -----------------------
# Label 'dtp', 'Literature & Fiction'
#  Support is 93833
# 1 TOPIC:
#  [(0,
#    '0.004*"one" + 0.003*"new" + 0.003*"also" + 0.002*"time" + 0.002*"like" + '
#    '0.002*"marriage" + 0.002*"certificate" + 0.002*"translation" + '
#    '0.002*"brazilian" + 0.002*"first"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"–" + 0.003*"new" + 0.003*"also" + 0.002*"time" + '
#    '0.002*"music" + 0.002*"years" + 0.002*"get" + 0.002*"first" + 0.002*"like"'),
#   (1,
#    '0.004*"one" + 0.003*"new" + 0.002*"time" + 0.002*"like" + 0.002*"also" + '
#    '0.002*"first" + 0.002*"would" + 0.002*"dating" + 0.002*"two" + 0.002*"get"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"new" + 0.003*"one" + 0.003*"also" + 0.003*"time" + 0.002*"music" + '
#    '0.002*"like" + 0.002*"first" + 0.002*"years" + 0.002*"art" + 0.002*"many"'),
#   (1,
#    '0.004*"one" + 0.003*"like" + 0.003*"music" + 0.002*"new" + 0.002*"time" + '
#    '0.002*"get" + 0.002*"also" + 0.002*"metroid" + 0.002*"mobile" + '
#    '0.002*"first"'),
#   (2,
#    '0.005*"pdf" + 0.004*"one" + 0.003*"short" + 0.003*"description" + '
#    '0.003*"file" + 0.002*"also" + 0.002*"new" + 0.002*"time" + 0.002*"like" + '
#    '0.002*"get"')]
#
#
# -----------------------
# Label 'dtp', 'Medicine & Health Sciences'
#  Support is 14219
# 1 TOPIC:
#  [(0,
#    '0.003*"health" + 0.003*"also" + 0.003*"may" + 0.003*"one" + 0.003*"care" + '
#    '0.003*"medical" + 0.002*"treatment" + 0.002*"time" + 0.002*"patients" + '
#    '0.002*"new"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"care" + 0.003*"may" + 0.003*"time" + '
#    '0.003*"health" + 0.002*"people" + 0.002*"new" + 0.002*"like" + '
#    '0.002*"work"'),
#   (1,
#    '0.006*"health" + 0.004*"treatment" + 0.004*"also" + 0.004*"may" + '
#    '0.003*"patients" + 0.003*"medical" + 0.003*"skin" + 0.003*"research" + '
#    '0.002*"cancer" + 0.002*"used"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.004*"health" + 0.004*"research" + 0.004*"1" + 0.003*"0" + 0.003*"may" + '
#    '0.003*"one" + 0.003*"also" + 0.002*"new" + 0.002*"students" + 0.002*"2"'),
#   (1,
#    '0.005*"may" + 0.005*"also" + 0.004*"treatment" + 0.003*"one" + 0.003*"body" '
#    '+ 0.003*"help" + 0.003*"health" + 0.002*"use" + 0.002*"people" + '
#    '0.002*"time"'),
#   (2,
#    '0.005*"care" + 0.004*"health" + 0.004*"dental" + 0.004*"patients" + '
#    '0.003*"medical" + 0.003*"one" + 0.003*"also" + 0.003*"dr" + 0.003*"new" + '
#    '0.003*"time"')]
#
#
# -----------------------
# Label 'dtp', 'None'
#  Support is 71204
# 1 TOPIC:
#  [(0,
#    '0.003*"one" + 0.003*"also" + 0.003*"new" + 0.002*"time" + 0.002*"us" + '
#    '0.002*"like" + 0.002*"get" + 0.002*"make" + 0.002*"may" + 0.002*"first"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.003*"also" + 0.003*"one" + 0.003*"new" + 0.002*"time" + 0.002*"download" '
#    '+ 0.002*"may" + 0.002*"business" + 0.002*"make" + 0.002*"us" + '
#    '0.002*"well"'),
#   (1,
#    '0.003*"one" + 0.003*"new" + 0.003*"also" + 0.002*"time" + 0.002*"like" + '
#    '0.002*"us" + 0.002*"years" + 0.002*"get" + 0.002*"born" + 0.002*"work"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"also" + 0.003*"new" + 0.003*"one" + 0.002*"time" + 0.002*"us" + '
#    '0.002*"years" + 0.002*"work" + 0.002*"water" + 0.002*"like" + 0.002*"–"'),
#   (1,
#    '0.003*"also" + 0.003*"one" + 0.002*"new" + 0.002*"home" + 0.002*"located" + '
#    '0.002*"service" + 0.002*"area" + 0.002*"free" + 0.002*"room" + 0.002*"us"'),
#   (2,
#    '0.003*"one" + 0.003*"new" + 0.003*"also" + 0.003*"like" + 0.003*"time" + '
#    '0.002*"us" + 0.002*"people" + 0.002*"make" + 0.002*"get" + 0.002*"use"')]
#
#
# -----------------------
# Label 'dtp', 'Politics & Social Sciences'
#  Support is 61577
# 1 TOPIC:
#  [(0,
#    '0.003*"also" + 0.003*"one" + 0.003*"new" + 0.002*"time" + 0.002*"people" + '
#    '0.002*"work" + 0.002*"business" + 0.002*"may" + 0.002*"us" + 0.002*"years"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"also" + 0.003*"women" + 0.003*"law" + 0.003*"one" + 0.003*"men" + '
#    '0.002*"born" + 0.002*"registered" + 0.002*"number" + 0.002*"vote" + '
#    '0.002*"time"'),
#   (1,
#    '0.004*"insurance" + 0.003*"new" + 0.003*"also" + 0.003*"one" + '
#    '0.002*"business" + 0.002*"time" + 0.002*"may" + 0.002*"services" + '
#    '0.002*"us" + 0.002*"work"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"new" + 0.003*"business" + 0.003*"also" + 0.003*"information" + '
#    '0.003*"services" + 0.003*"may" + 0.002*"work" + 0.002*"us" + 0.002*"one" + '
#    '0.002*"time"'),
#   (1,
#    '0.006*"one" + 0.004*"isd" + 0.004*"also" + 0.004*"angel" + 0.002*"city" + '
#    '0.002*"new" + 0.002*"first" + 0.002*"god" + 0.002*"like" + 0.002*"world"'),
#   (2,
#    '0.003*"students" + 0.003*"one" + 0.003*"time" + 0.002*"also" + 0.002*"new" '
#    '+ 0.002*"work" + 0.002*"business" + 0.002*"people" + 0.002*"may" + '
#    '0.002*"service"')]
#
#
# -----------------------
# Label 'dtp', 'Science & Math'
#  Support is 4951
# 1 TOPIC:
#  [(0,
#    '0.003*"also" + 0.003*"one" + 0.002*"new" + 0.002*"species" + 0.002*"may" + '
#    '0.002*"water" + 0.002*"time" + 0.002*"many" + 0.002*"research" + '
#    '0.002*"use"')]
#
#
# 2 TOPICS:
#  [(0,
#    '0.004*"also" + 0.003*"one" + 0.003*"research" + 0.003*"new" + '
#    '0.002*"species" + 0.002*"may" + 0.002*"water" + 0.002*"time" + 0.002*"use" '
#    '+ 0.002*"information"'),
#   (1,
#    '0.003*"one" + 0.003*"also" + 0.003*"fishing" + 0.003*"species" + '
#    '0.002*"fish" + 0.002*"plant" + 0.002*"water" + 0.002*"plants" + '
#    '0.002*"many" + 0.002*"may"')]
#
#
# 3 TOPICS:
#  [(0,
#    '0.003*"species" + 0.003*"also" + 0.003*"plant" + 0.003*"one" + 0.003*"may" '
#    '+ 0.002*"plants" + 0.002*"water" + 0.002*"long" + 0.002*"flowers" + '
#    '0.002*"leaves"'),
#   (1,
#    '0.003*"also" + 0.003*"research" + 0.003*"new" + 0.003*"one" + 0.002*"us" + '
#    '0.002*"students" + 0.002*"use" + 0.002*"may" + 0.002*"species" + '
#    '0.002*"time"'),
#   (2,
#    '0.004*"one" + 0.004*"also" + 0.003*"time" + 0.002*"new" + 0.002*"may" + '
#    '0.002*"many" + 0.002*"first" + 0.002*"two" + 0.002*"like" + 0.002*"used"')]
#
#
# -----------------------
